# %%
from bs4 import BeautifulSoup
#import urllib.request             # HTTP Request and Response
#from urllib.parse import quote    # UTF-8 to ASCII for URL
from urllib.parse import urlparse, parse_qs # URL Parsing
import requests
import re
import json

# %%
#-*- coding: utf-8 -*-
SHOP_URL = "http://match-made.co.kr/"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

# %%
list_html = requests.get(url=SHOP_URL, headers=headers).content
list_lxml = BeautifulSoup(list_html, 'lxml', from_encoding='utf-8')

# %%
url_list = [SHOP_URL+i.get('href') for i in list_lxml.select('div.thumbnail > a')]
img_list = ['http:'+i.get('src') for i in list_lxml.select('div.thumbnail > a > img')]
name_list = [i.find_all(text=True)[0] for i in list_lxml.select('div.description > div.name > a > span')]
for i, name in enumerate(name_list):
    if name == '상품명':
        del name_list[i]

# %%
print(len(url_list))
print(len(img_list))
print(len(name_list))
# Out:
# 300
# 300
# 300

# %%
name_list
# Out:
# ['ANTIQULOTHES(NEW)',
#  'POLO Ralph Lauren',
#  'BEAMS',
#  'A.P.C',
#  "PAL'LAS PALACE",
#  'LL.BEAN',
#  'SWEAT SHIRTS',
#  'J.W. BRINE',
#  'SUGAR CANE',
#  'GAIJIN MADE',
#  'SCANNER FUNDAMENTAL PRODUCT',
#  'KEARNEY HOUSE',
#  "ISSEY MIYAKE 'WINDCOAT'",
#  'N.HOOLYWOOD',
#  'GL.BOWRON',
#  'NONE',
#  'BURBERRY',
#  '45rpm',
#  'VETRA×HARRIS TWEED',
#  'KLEIN PLUS HOMME(NEW)',
#  'HIGH-LIGHT CAVALET',
#  "ANTIQULOTHES 'WORKS'",
#  'ANTI BALLISTIC',
#  'NORTH FACE',
#  'CARHARTT',
#  "LEVI'S 70599",
#  'BURBERRY',
#  'Handknit in Norway',
#  'DeSTYLE',
#  "80's Original A-2 Deck Jacket",
#  "LEVI'S",
#  'SCANNER FUNDAMENTAL PRODUCT',
#  "BLUE BLUE 'ARIGATO'",
#  'WOOLRICH(NEW)',
#  'GLOVERALL',
#  'DRESSTERIOR',
#  'HOLLYWOOD RANCH MARKET',
#  "70's Vintage Cafe Racer",
#  'ALPHA N-2B',
#  'STUSSY',
#  'DUVETICA×CERRUTI',
#  'COMME des GARCONS HOMME',
#  'NEMETH',
#  'BAGUTTA',
#  'robe de chambre COMME des GARCONS',
#  'EDIFICE',
#  'hanakazari',
#  'MARGARET HOWELL',
#  'DALE OF NORWAY',
#  "HENRY COTTON'S",
#  'BALENCIAGA',
#  'ORIHICA',
#  'ORIHICA',
#  'HAI SPORTING GEAR by ISSEY MIYAKE',
#  'HAI SPORTING GEAR by ISSEY MIYAKE',
#  'JOHN MOLLOY',
#  "TSUMORI CHISATO 'CATS'",
#  "PAL'LAS PALACE",
#  'SAMANSA MOS2',
#  'SAMANSA MOS2',
#  'relume JOURNAL STANDARD',
#  'FARIANI×MOON TWEED',
#  'Do CLASSE',
#  '23KU HOMME',
#  'SCHIATTI',
#  'CENCINI',
#  'COLUMBIA(NEW)',
#  'MONT BELL',
#  'CANADIAN SWEATER COMPANY',
#  'ENGINEERED GARMENTS',
#  'MARGARET HOWELL',
#  'TRADITIONAL WEATHERWEAR',
#  "PAL'LAS PALACE",
#  'Ne-net',
#  'ANTONIO LAVERDA',
#  'NORTH FACE',
#  'UNITED ARROWS',
#  'DANTON',
#  'NORBIT by Hiroshi Nozawa',
#  'TABLOID NEWS',
#  'EVISU',
#  "DIESEL 'CLUSHY'",
#  'MACK DADDY',
#  'G-STAR RAW',
#  'EMPORIO ARMANI',
#  'SIERRA DESIGNS',
#  'TOMORROWLAND',
#  'SPUTNIK',
#  'URBAN RESEARCH',
#  'MARGARET HOWELL',
#  'UNIS',
#  'noue-rue',
#  'MINNETONKA',
#  'PAUL STUART',
#  'DRY BONES',
#  'A.P.C.',
#  'DOUBLES',
#  'CATH KIDSTON(NEW)',
#  'Handmade Shouler Bag',
#  'Handmade Tote',
#  'Handmade Tote',
#  'KABRI',
#  'GIORGIO ARMANI',
#  'POLO Ralph Lauren',
#  'ROYAL SCOT',
#  'HIGHLAND2000',
#  'KATHARINE HAMNETT',
#  'Made in Italy',
#  'GILBERT WILSON of HAWICK',
#  'LOTHLORIAN(NEW)',
#  'Jayfor of Auchtermuchty',
#  'ROBERT MACKIE',
#  'ENGINEERED GARMENTS',
#  'NEPENTHES',
#  'FREEMANS SPORTING CLUB',
#  'JOHNSTON',
#  'RIDING HIGH',
#  'RALPH LAUREN',
#  'POLO COUNTRY',
#  'POLO Ralph Lauren',
#  'MARGARET HOWELL',
#  'Ne-net',
#  'DIESEL',
#  "CHAMPION 'TECH WEAVE'",
#  'R.NEWBOLD',
#  'POLO SPORT',
#  'HARE',
#  'EDIFICE',
#  'ANTIQULOTHES(NEW)',
#  'MARGARET HOWELL',
#  "PAL'LAS PALACE",
#  'GL.BOWRON',
#  'SBAENA×HARRIS TWEED',
#  'ISSEY MIYAKE',
#  'DIESEL',
#  'Les Copains Jeans',
#  'FTC',
#  'TABLOID NEWS',
#  'MELTON',
#  'tricot COMME des GARCONS',
#  'FRAPBOIS×DICKIES',
#  'JOURNAL STANDARD×IN.TES.PRA',
#  'Le Minor',
#  'BRENTS SPORTSWEAR',
#  'POLO Ralph Lauren',
#  'SIMPLICTE PLUS',
#  'SUGAR CANE 1966',
#  'CARHARTT',
#  'GRAMICCI',
#  'TOM FORD',
#  'BOGLIOLI',
#  'DUVETICA×CERRUTI',
#  'MARGARET HOWELL',
#  'PRPS',
#  'ISSEY MIYAKE',
#  'BURBERRY',
#  '45rpm',
#  'MSGM',
#  'BLUGIRL by BLUMARINE',
#  '45rpm',
#  'BEAMS',
#  'JOHNLAWRENCESULLIVAN',
#  '45rpm',
#  'GRAMICCI',
#  "LEVI'S 'Big E' 503BXX",
#  "Vintage LEVI'S 501",
#  'STANDARD WEAR by CIAOPANIC',
#  'mint designs',
#  "L'ESSAGE JOURNAL STANDARD",
#  'DOOA',
#  'COEN by UNITED ARROWS',
#  'CASELY-HATFORD for BANEYS NEWYORK',
#  'ZANONE',
#  'GRAND PHASE',
#  'BURBERRY',
#  "90's LEVI'S SILVER TAB×JAMIROQUAI",
#  'ETNIC',
#  "90's ADIDAS",
#  'BAJA HOODIE',
#  'ADOLFO DOMINGUEZ',
#  'HERMES',
#  'Japan Handmade Shibori',
#  'DeDanae',
#  'PURE CASHMERE MUFFLER',
#  'ALVIERO MARTINI(NEW)',
#  'Mühlbauer',
#  'HATS&DREAMS',
#  'HATS&DREAMS',
#  'CA4LA',
#  'THEORY',
#  'OVERRIDE',
#  'CA4LA',
#  'CA4LA',
#  'DeDanae',
#  'STEWART AUSTIN',
#  'Conte of Florence',
#  'OVERRIDE×TOP KNOT',
#  'CASTANO',
#  'BEAMS',
#  'NEW ERA',
#  'GUCCI',
#  'SHEARLING JACKET',
#  'ICEBERG',
#  'COLUMBIA(NEW)',
#  'HYSTERIC GLAMOUR',
#  'ROYAL TRADITION',
#  'SUIT SELECT 21',
#  'JOHNS HAMER by OCTOPUS ARMNY',
#  '417 by EDIFICE',
#  'KEMPEL',
#  'HERNO',
#  'BURBERRY',
#  'KANATA',
#  'MAISON SCOTCH',
#  'RALPH LAUREN',
#  'BOGGI MILANO',
#  'CERRUTI',
#  'NEWCREATE×HARRIS TWEED',
#  'FranCist_MOR.K.S',
#  'AVIREX B-3',
#  'WOOLRICH',
#  'LAVENHAM',
#  'ADIDAS',
#  "I WISH by Y's bis",
#  'MARGARET HOWELL',
#  'JURGEN LEHL',
#  "THEORY 'LONAN'",
#  'tumugu',
#  'junhashimoto×NANO·UNIVERSE',
#  'TIME AFTER TIME',
#  '45rpm',
#  'BRAGENT',
#  'SANTASTIC',
#  'KATHARINE HAMNETT',
#  "LEVI'S",
#  'CARHARTT',
#  'SCHOTT NYC',
#  "NORTH FACE 'SUMMIT SERIES'",
#  'LOGOS',
#  'COOGI',
#  'SIR NEW YORK(NEW)',
#  'FRAPBOIS',
#  'BACKDROP×CHAMPION',
#  'ROKX',
#  'AIGLE',
#  'LL.BEAN',
#  'DANTON',
#  'COMME des GARCONS HOMME',
#  'GGD',
#  'KROFOFRO',
#  "SCHOTT NYC '740N'",
#  'add',
#  'NORTH FACE',
#  'GIESSWEIN',
#  'kolor',
#  'EMPORIO ARMANI',
#  'POLO Ralph Lauren',
#  'ON THE NEIGE STYLE(NEW)',
#  'British Army Sweater',
#  'OMNIGOD',
#  'ALFASPIN',
#  'INPAICHTHYS KERRI',
#  'FARFIELD ORIGIANL',
#  'KU.USA',
#  'EDDIE BAUER',
#  'HEART MARKET',
#  'FLOW',
#  "PORTER 'FIELD'",
#  'KARRIMOR',
#  'Indigo Linen Tote',
#  'deux C',
#  'INDIANA JONES',
#  'RALPH LAUREN',
#  'RALPH LAUREN(NEW)',
#  'Japan Handmade Shibori',
#  'CLOSSHI×HARRIS TWEED',
#  'GRAMICCI',
#  'FRANZI for TIE RACK(NEW)',
#  'MABAN of SCOTLAND',
#  'LIBERTY',
#  'RALPH LAUREN',
#  'POLO Ralph Lauren',
#  'POLO Ralph Lauren(NEW)',
#  'PAUL SMITH',
#  'GAIJIN MADE',
#  'MABAN of SCOTLAND',
#  "VIKTOR&ROLF 'Monsieur'",
#  'PRADA',
#  "Y's",
#  'BANANA REPUBLIC',
#  'BRANDED GARMENTS',
#  'DANTON',
#  'KATHARINE HAMNETT',
#  'Original USAF All Weather Trench Coat with Liner',
#  'CORINTH MFG Co.',
#  'Original Belgian M-70 Parka with Liner',
#  'COMME des GARCONS',
#  "Y's",
#  'ZUCCA',
#  'DAHLIA']
